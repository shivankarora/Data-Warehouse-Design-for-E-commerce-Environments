# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
len(df['Description'].unique())
# Out:
# 4224

# %%
df['UnitPrice'].max()
# Out:
# 38970.0

# %%
df['UnitPrice'].min()
# Out:
# -11062.06

# %%
df[df['UnitPrice'] ==-11062.06 ]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df['Country'].value_counts().sort_values(ascending=False)
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
#This Dataset is highly based aroud European Countries

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['InvoiceDate'] = df['InvoiceDate'].dt.to_period('M')

# %%
len(df['InvoiceNo'].unique())
# Out:
# 25900

# %%
df[df['Description']=='Adjust bad debt']
# Out:
#        InvoiceNo StockCode      Description  Quantity InvoiceDate  UnitPrice  \
# 299982   A563185         B  Adjust bad debt         1     2011-08   11062.06
# 299983   A563186         B  Adjust bad debt         1     2011-08  -11062.06
# 299984   A563187         B  Adjust bad debt         1     2011-08  -11062.06
#
#         CustomerID         Country
# 299982         NaN  United Kingdom
# 299983         NaN  United Kingdom
# 299984         NaN  United Kingdom

# %%
df[df['UnitPrice']<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity InvoiceDate  UnitPrice  \
# 299983   A563186         B  Adjust bad debt         1     2011-08  -11062.06
# 299984   A563187         B  Adjust bad debt         1     2011-08  -11062.06
#
#         CustomerID         Country
# 299983         NaN  United Kingdom
# 299984         NaN  United Kingdom

# %%
df = df[df['UnitPrice'] >= 0]

# %%
df['StockCode'].value_counts().idxmax()
# Out:
# '85123A'

# %%
df[df['StockCode'] == '85123A']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 0         536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 49        536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66        536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 220       536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 262       536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# ...          ...       ...                                 ...       ...
# 539342    581439    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
# 539979    581452    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# 540217    581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 540837    581492    85123A  CREAM HANGING HEART T-LIGHT HOLDER         3
# 541639    581538    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
stockcode_counts = df['StockCode'].value_counts()
second_highest_count = stockcode_counts.sort_values(ascending=False).iloc[3]
second_highest_stockcode = stockcode_counts[stockcode_counts == second_highest_count].index[0]

# %%
print(f"The stockcode '{second_highest_stockcode}' has the second-highest count of {second_highest_count}.")
# Out:
# The stockcode '47566' has the second-highest count of 1727.

# %%
df[df['StockCode'] == '85099B']
# Out:
#        InvoiceNo StockCode              Description  Quantity InvoiceDate  \
# 177       536386    85099B  JUMBO BAG RED RETROSPOT       100     2010-12
# 234       536390    85099B  JUMBO BAG RED RETROSPOT       100     2010-12
# 533       536409    85099B  JUMBO BAG RED RETROSPOT         2     2010-12
# 790       536464    85099B  JUMBO BAG RED RETROSPOT         1     2010-12
# 1069      536522    85099B  JUMBO BAG RED RETROSPOT         1     2010-12
# ...          ...       ...                      ...       ...         ...
# 538603    581412    85099B  JUMBO BAG RED RETROSPOT         3     2011-12
# 538913    581421    85099B  JUMBO BAG RED RETROSPOT         9     2011-12
# 539338    581439    85099B  JUMBO BAG RED RETROSPOT         1     2011-12
# 540434    581486    85099B  JUMBO BAG RED RETROSPOT        10     2011-12
# 541536    581498    85099B  JUMBO BAG RED RETROSPOT         5     2011-12
#
#         UnitPrice  CustomerID         Country
# ...

# %%
df[(df['UnitPrice'] >= 500.0) & (df['UnitPrice'] <= 100000.0)]
# Out:
#        InvoiceNo StockCode     Description  Quantity InvoiceDate  UnitPrice  \
# 1814      536544       DOT  DOTCOM POSTAGE         1     2010-12     569.77
# 3041      536592       DOT  DOTCOM POSTAGE         1     2010-12     607.49
# 6165      536876       DOT  DOTCOM POSTAGE         1     2010-12     887.52
# 10812     537237       DOT  DOTCOM POSTAGE         1     2010-12     863.74
# 11381     537240       DOT  DOTCOM POSTAGE         1     2010-12     940.87
# ...          ...       ...             ...       ...         ...        ...
# 536834    581219       DOT  DOTCOM POSTAGE         1     2011-12    1008.96
# 537254    581238       DOT  DOTCOM POSTAGE         1     2011-12    1683.75
# 539368    581439       DOT  DOTCOM POSTAGE         1     2011-12     938.59
# 540908    581492       DOT  DOTCOM POSTAGE         1     2011-12     933.17
# 541540    581498       DOT  DOTCOM POSTAGE         1     2011-12    1714.17
#
#         CustomerID         Country
# ...

# %%
df = df[df['StockCode'] != 'DOT']

# %%
df = df[df['StockCode'] != 'AMAZONFEE']

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df1 = df[df['StockCode'] == '85123A']

# %%
df1
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 0         536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 49        536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66        536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 220       536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 262       536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# ...          ...       ...                                 ...       ...
# 539342    581439    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
# 539979    581452    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# 540217    581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 540837    581492    85123A  CREAM HANGING HEART T-LIGHT HOLDER         3
# 541639    581538    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Let's study for one best selling item
df1.drop('StockCode', axis =1 ,inplace=True)
df1.drop('Description', axis =1 ,inplace=True)
# Out:
# /var/folders/tp/t4y3f8l157g5z9_0_thqg8h40000gn/T/ipykernel_24546/21862895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('StockCode', axis =1 ,inplace=True)
# /var/folders/tp/t4y3f8l157g5z9_0_thqg8h40000gn/T/ipykernel_24546/21862895.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('Description', axis =1 ,inplace=True)

# %%
df1
# Out:
#        InvoiceNo  Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 0         536365         6     2010-12       2.55     17850.0  United Kingdom
# 49        536373         6     2010-12       2.55     17850.0  United Kingdom
# 66        536375         6     2010-12       2.55     17850.0  United Kingdom
# 220       536390        64     2010-12       2.55     17511.0  United Kingdom
# 262       536394        32     2010-12       2.55     13408.0  United Kingdom
# ...          ...       ...         ...        ...         ...             ...
# 539342    581439         1     2011-12       5.79         NaN  United Kingdom
# 539979    581452        32     2011-12       2.55     17675.0  United Kingdom
# 540217    581472         6     2011-12       2.95     15796.0  United Kingdom
# 540837    581492         3     2011-12       5.79         NaN  United Kingdom
# 541639    581538         1     2011-12       2.95     14446.0  United Kingdom
#
# [2313 rows x 6 columns]

# %%
len(df1['InvoiceNo'].unique())
# Out:
# 2246

# %%
df1 = df1.dropna()

# %%
len(df1['InvoiceNo'].unique())
# Out:
# 2020

# %%
df1
# Out:
#        InvoiceNo  Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 0         536365         6     2010-12       2.55     17850.0  United Kingdom
# 49        536373         6     2010-12       2.55     17850.0  United Kingdom
# 66        536375         6     2010-12       2.55     17850.0  United Kingdom
# 220       536390        64     2010-12       2.55     17511.0  United Kingdom
# 262       536394        32     2010-12       2.55     13408.0  United Kingdom
# ...          ...       ...         ...        ...         ...             ...
# 538708    581412         4     2011-12       2.95     14415.0  United Kingdom
# 539083    581432        32     2011-12       2.55     13798.0  United Kingdom
# 539979    581452        32     2011-12       2.55     17675.0  United Kingdom
# 540217    581472         6     2011-12       2.95     15796.0  United Kingdom
# 541639    581538         1     2011-12       2.95     14446.0  United Kingdom
#
# [2077 rows x 6 columns]

# %%
df1['Country'].unique()
# Out:
# array(['United Kingdom', 'Spain', 'Cyprus', 'EIRE', 'Portugal',
#        'Netherlands', 'Australia', 'Singapore', 'Switzerland', 'Finland',
#        'Channel Islands', 'France', 'Malta', 'Italy', 'Israel', 'Germany'],
#       dtype=object)

# %%
df1['Country'].value_counts().sort_values(ascending=False)
# Out:
# United Kingdom     1987
# EIRE                 41
# Spain                11
# Netherlands           6
# Italy                 6
# Cyprus                5
# Channel Islands       4
# Finland               3
# France                3
# Portugal              2
# Singapore             2
# Switzerland           2
# Israel                2
# Australia             1
# Malta                 1
# Germany               1
# Name: Country, dtype: int64

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID',
#        'Country'],
#       dtype='object')

# %%
avg_unit_prices_by_country = df1.groupby('Country')['UnitPrice'].mean().sort_values(ascending=False)

# %%
avg_unit_prices_by_country
# Out:
# Country
# Finland            2.950000
# Italy              2.950000
# Australia          2.950000
# Channel Islands    2.950000
# Germany            2.950000
# Israel             2.950000
# Malta              2.950000
# Portugal           2.950000
# Spain              2.950000
# United Kingdom     2.892536
# EIRE               2.842683
# France             2.816667
# Netherlands        2.816667
# Cyprus             2.790000
# Singapore          2.750000
# Switzerland        2.550000
# Name: UnitPrice, dtype: float64

# %%
df2 = df[df['StockCode']== '85099B']

# %%
avg_unit_prices_by_country_1 = df2.groupby('Country')['UnitPrice'].mean().sort_values(ascending=False)

# %%
avg_unit_prices_by_country_1
# Out:
# Country
# United Kingdom     2.506382
# Italy              2.080000
# RSA                2.080000
# USA                2.080000
# Sweden             2.080000
# Cyprus             2.080000
# Finland            2.058333
# Spain              2.054000
# France             2.053333
# Germany            2.051111
# EIRE               2.036667
# Switzerland        2.036667
# Portugal           2.036667
# Belgium            2.028000
# Singapore          2.015000
# Channel Islands    2.010000
# Austria            1.950000
# Australia          1.938000
# Norway             1.790000
# Netherlands        1.730000
# Name: UnitPrice, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(avg_unit_prices_by_country_1.index, avg_unit_prices_by_country_1.values)


plt.title('Average Unit Price by Country')
plt.xlabel('Country')
plt.ylabel('Average Unit Price')

# rotate the x-axis labels for better visibility
plt.xticks(rotation=90)

# display the graph
plt.show()

# %%
#let's find out higher price product

# %%
df[df['UnitPrice']>50]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 246       536392     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 1665      536544     22769        CHALKBOARD KITCHEN ORGANISER         1
# 2738      536592     22503           CABIN BAG VINTAGE PAISLEY         1
# 3790      536676     21769         VINTAGE POST OFFICE CABINET         1
# 4989      536835     22655         VINTAGE RED KITCHEN CABINET         1
# ...          ...       ...                                 ...       ...
# 528087   C580726      CRUK                     CRUK Commission        -1
# 533082   C581009         M                              Manual        -1
# 535003    581179      POST                             POSTAGE         1
# 535976    581217    84078A    SET/4 WHITE RETRO STORAGE CUBES          1
# 541541   C581499         M                              Manual        -1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df3 = df[df['StockCode'] == 22503]

# %%
avg_unit_prices_by_country_3 = df3.groupby('Country')['UnitPrice'].mean().sort_values(ascending=False)

# %%
avg_unit_prices_by_country_3
# Out:
# Country
# Hong Kong         29.950000
# Portugal          29.950000
# EIRE              24.950000
# United Kingdom    22.759643
# Germany           18.483333
# Australia         12.750000
# Poland            12.750000
# Name: UnitPrice, dtype: float64

# %%
plt.bar(avg_unit_prices_by_country_3.index, avg_unit_prices_by_country_3.values)


plt.title('Average Unit Price by Country')
plt.xlabel('Country')
plt.ylabel('Average Unit Price')

# rotate the x-axis labels for better visibility
plt.xticks(rotation=90)

# display the graph
plt.show()

# %%
df3
# Out:
#        InvoiceNo StockCode                Description  Quantity  \
# 2738      536592     22503  CABIN BAG VINTAGE PAISLEY         1
# 5243      536851     22503  CABIN BAG VINTAGE PAISLEY         6
# 13977     537440     22503  CABIN BAG VINTAGE PAISLEY         1
# 31795     539013     22503  CABIN BAG VINTAGE PAISLEY         3
# 34507     539401     22503  CABIN BAG VINTAGE PAISLEY        12
# 42108     539958     22503  CABIN BAG VINTAGE PAISLEY         1
# 43855     540150     22503  CABIN BAG VINTAGE PAISLEY         3
# 50494     540551     22503  CABIN BAG VINTAGE PAISLEY         1
# 58999     541267     22503  CABIN BAG VINTAGE PAISLEY         3
# 63106     541520     22503  CABIN BAG VINTAGE PAISLEY         3
# 65285     541695     22503  CABIN BAG VINTAGE PAISLEY         1
# 70281     542001     22503  CABIN BAG VINTAGE PAISLEY         3
# 85408    C543469     22503  CABIN BAG VINTAGE PAISLEY        -1
# 89297     543899     22503  CABIN BAG VINTAGE PAISLEY         6
# ...

# %%
df4 = df[df['Country'] != 'United Kingdom']

# %%
df4
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# ...

# %%
df4[df4['UnitPrice'] >50]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 34699     539421     22929        SCHOOL DESK AND CHAIR          1
# 39777     539688        C2                      CARRIAGE         1
# 45622    C540271         M                        Manual        -1
# 54382     540946     22656  VINTAGE BLUE KITCHEN CABINET         1
# 54395     540946     22655   VINTAGE RED KITCHEN CABINET         1
# ...          ...       ...                           ...       ...
# 465424    576234         M                        Manual         1
# 475499    576897      POST                       POSTAGE         7
# 475511   C576898      POST                       POSTAGE        -2
# 485574    577609      POST                       POSTAGE         1
# 535003    581179      POST                       POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID    Country
# 34699  2010-12-17 14:21:00       65.0     14016.0       EIRE
# ...

# %%
df4[df4['StockCode'] == 22929]
# Out:
#        InvoiceNo StockCode             Description  Quantity  \
# 34699     539421     22929  SCHOOL DESK AND CHAIR          1
# 233514    557472     22929  SCHOOL DESK AND CHAIR          2
# 304850    563613     22929  SCHOOL DESK AND CHAIR          2
# 347147    567290     22929  SCHOOL DESK AND CHAIR          4
# 398347    571239     22929  SCHOOL DESK AND CHAIR          1
# 420305    572886     22929  SCHOOL DESK AND CHAIR          1
#
#                InvoiceDate  UnitPrice  CustomerID      Country
# 34699  2010-12-17 14:21:00      65.00     14016.0         EIRE
# 233514 2011-06-20 13:27:00      65.00     12432.0       Norway
# 304850 2011-08-18 08:49:00      65.00     12688.0       Israel
# 347147 2011-09-19 11:54:00      57.95     14646.0  Netherlands
# 398347 2011-10-14 14:54:00      65.00     12744.0    Singapore
# 420305 2011-10-26 13:46:00      65.00     12448.0        Spain

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df4[df4['UnitPrice']>20]
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 1423      536540        C2                       CARRIAGE         1
# 5325      536858      POST                        POSTAGE         2
# 7139      536990      POST                        POSTAGE         1
# 7237      537022      POST                        POSTAGE         2
# 7952      537065    84963A    PINK PAINTED KASHMIRI CHAIR         4
# ...          ...       ...                            ...       ...
# 531431    580955      POST                        POSTAGE         1
# 533678    581098     22782  SET 3 WICKER STORAGE BASKETS          2
# 535003    581179      POST                        POSTAGE         1
# 535048    581182      POST                        POSTAGE         4
# 536968    581232      POST                        POSTAGE         4
#
#                InvoiceDate  UnitPrice  CustomerID      Country
# 1423   2010-12-01 14:05:00      50.00     14911.0         EIRE
# ...

# %%
df5 =df[df['StockCode'] == 47566]

# %%
df5
# Out:
#        InvoiceNo StockCode    Description  Quantity         InvoiceDate  \
# 5535      536864     47566  PARTY BUNTING         1 2010-12-03 11:27:00
# 5656      536865     47566  PARTY BUNTING         3 2010-12-03 11:28:00
# 6022      536876     47566  PARTY BUNTING         2 2010-12-03 11:36:00
# 6572      536956     47566  PARTY BUNTING         5 2010-12-03 12:43:00
# 7904      537065     47566  PARTY BUNTING         5 2010-12-05 11:57:00
# ...          ...       ...            ...       ...                 ...
# 537784    581345     47566  PARTY BUNTING         5 2011-12-08 12:15:00
# 538825    581417     47566  PARTY BUNTING         8 2011-12-08 15:01:00
# 539027    581426     47566  PARTY BUNTING         1 2011-12-08 15:31:00
# 540534    581492     47566  PARTY BUNTING         2 2011-12-09 10:03:00
# 541318    581497     47566  PARTY BUNTING         5 2011-12-09 10:23:00
#
#         UnitPrice  CustomerID         Country
# 5535         9.32         NaN  United Kingdom
# ...

# %%
avg_unit_prices_by_country_4 = df3.groupby('Country')['UnitPrice'].mean().sort_values(ascending=False)

# %%
avg_unit_prices_by_country_4
# Out:
# Country
# Hong Kong         29.950000
# Portugal          29.950000
# EIRE              24.950000
# United Kingdom    22.759643
# Germany           18.483333
# Australia         12.750000
# Poland            12.750000
# Name: UnitPrice, dtype: float64

# %%
plt.bar(avg_unit_prices_by_country_4.index, avg_unit_prices_by_country_4.values)


plt.title('Average Unit Price by Country')
plt.xlabel('Country')
plt.ylabel('Average Unit Price')

# rotate the x-axis labels for better visibility
plt.xticks(rotation=90)

# display the graph
plt.show()

# %%
#As We can see The prices are highest in areas like HongKong and Portugal while way less in poland and Austrailia

# %%
#Were the higher-priced items more prevalent in some markets?
# yes some products were sold at higher price at certain country or demographic area
